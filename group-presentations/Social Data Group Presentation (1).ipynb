# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/ripple1992/Run/master/1.jpg)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/ripple1992/Run/master/2.jpg)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/ripple1992/Run/master/3.jpg)

# %% [markdown]
# # Where can we find social data?
#
#
#
#
# ##  <font color='red'>Stanford Large Network Dataset Collection</font>
# https://snap.stanford.edu/data/
# ![title](https://github.com/YifangJia/1127/blob/master/13.PNG?raw=true)
#
# ### social networks
# ![title](https://github.com/YifangJia/1127/blob/master/1.PNG?raw=true)
# ### Networks with ground-truth communities
# ![title](https://github.com/YifangJia/1127/blob/master/2.PNG?raw=true)
# ### Communication networks
# ![title](https://github.com/YifangJia/1127/blob/master/3.PNG?raw=true)
# ### Others:
# Citation networks
#
# Collaboration networks
#
# Internet peer-to-peer networks
#
# Location-based online social networks
#
# Memetracker and Twitter
#
# Online Communities
#
# ...
#
#
#
#
#
# ##  <font color='red'>The UCI Network Data Repository</font>
#
# http://networkdata.ics.uci.edu/index.html
#
# ![title](https://github.com/YifangJia/1127/blob/master/9.PNG?raw=true)
#
# ![title](https://github.com/YifangJia/1127/blob/master/14.PNG?raw=true)
#
# ![title](https://github.com/YifangJia/1127/blob/master/10.PNG?raw=true)
#
#
#
#
# ##  <font color='red'>Social Computing Data Repository at Arizona State University</font>
#
# http://socialcomputing.asu.edu/pages/datasets
#
# ![title](https://github.com/YifangJia/1127/blob/master/4.PNG?raw=true)
#
# ![title](https://github.com/YifangJia/1127/blob/master/5.PNG?raw=true)
#
#
# ![title](https://github.com/YifangJia/1127/blob/master/6.PNG?raw=true)
#
#
#
#
#
# ##  <font color='red'>The Koblenz Network Collection</font>
#
# http://konect.uni-koblenz.de/
#
# ![title](https://github.com/YifangJia/1127/blob/master/11.PNG?raw=true)
#
#
#
#
#
#
# ##  <font color='red'>NodeXL</font>
# http://nodexl.codeplex.com/
#
# ![title](https://github.com/YifangJia/1127/blob/master/12.PNG?raw=true)
#
# ![title](https://github.com/YifangJia/1127/blob/master/7.png?raw=true)
# ![title](https://github.com/YifangJia/1127/blob/master/8.png?raw=true)
#
# ##  <font color='red'>Other Sources:</font>
#
# http://networkrepository.com/soc.php
#
# http://www-personal.umich.edu/~mejn/netdata/
#
# http://proj.ise.bgu.ac.il/sns/datasets.html
#
# https://toreopsahl.com/datasets/

# %% [markdown]
# # Example of Social data (Code)
#
# ## Similarity with Urban data
#
# ## Differences from Urban data

# %% [markdown]
# # Example 1. Turn Your Twitter Timeline into a Word Cloud
# ![title](https://raw.githubusercontent.com/RubyRuan/ARC6818/master/my_twitter_wordcloud_2_small.jpg)
#
# ## Sorry!
# ## If you want to try it for yourself, you can learn from [here](http://sebastianraschka.com/Articles/2014_twitter_wordcloud.html).
#
#
# ## ·Create wordcloud with your own image and text data.
# ### Before we do this exercise, we should install [WordCloud](https://github.com/amueller/word_cloud).
# ### Notice: Maybe you need to install [C++ for 3.5](http://landinghub.visualstudio.com/visual-cpp-build-tools) or [C++ for 2.7](https://www.microsoft.com/en-us/download/confirmation.aspx?id=44266) in your computer before install WorldCloud

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
d = path.dirname('.')
text = open(path.join(d, "Harry Potter and the Sorcerer's Stone.txt")).read()
Harry_coloring = imread(path.join(d, "Harry Potter and the Sorcerer's Stone.png"))

# %%
wc = WordCloud(background_color="white",#set the backgroud color you like 
max_words=2000,                         #set the maximum number of words that you want to show your wordcloud
mask=Harry_coloring,                    #set the backgroup iamge
stopwords = set(STOPWORDS),  
max_font_size=40,                       #set the maximum size of word show in word cloud
random_state=42)

wc.generate(text)                       #create word cloud

image_colors = ImageColorGenerator(Harry_coloring)  #create colors from backgroud image

# %%
plt.imshow(wc)
plt.axis("off")

plt.figure()
# recolor wordcloud and show
# we could also give color_func=image_colors directly in the constructor
plt.imshow(wc.recolor(color_func=image_colors))
plt.axis("off")
# draw wordcloud which follow image's color
plt.figure()
plt.imshow(Harry_coloring, cmap=plt.cm.gray)
plt.axis("off")
plt.show()
# save image
wc.to_file(path.join(d, "Harry.png"))

## reference: https://github.com/amueller/word_cloud

# %% [markdown]
# # Example 2. Catch twitter user data base on Tweepy
# ## All code and comments below from [Adil Moujahid](http://adilmoujahid.com/posts/2014/07/twitter-analytics/)
#
# ## We will be using a Python library called Tweepy to connect to Twitter Streaming API and downloading the data. If you don't have Tweepy installed in your machine, go to this [link](https://github.com/tweepy/tweepy), and follow the installation instructions

# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

#Variables that contains the user credentials to access Twitter API 
#Make sure to enter your credentials into access_token, access_token_secret, consumer_key, and consumer_secret.
access_token = "ENTER YOUR ACCESS TOKEN"
access_token_secret = "ENTER YOUR ACCESS TOKEN SECRET"
consumer_key = "ENTER YOUR API KEY"
consumer_secret = "ENTER YOUR API SECRET"


#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    stream.filter(track=['python', 'javascript', 'ruby'])
# Out:
# {"created_at":"Mon Nov 28 12:20:18 +0000 2016","id":803211916889956352,"id_str":"803211916889956352","text":"RT @jazzhandsco: Check out this item in my Etsy shop https:\/\/t.co\/MtiGIsW3ID","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2369542400,"id_str":"2369542400","name":"SignYourName","screen_name":"signyournamenet","location":null,"url":"http:\/\/www.signyourname.net","description":null,"protected":false,"verified":false,"followers_count":14838,"friends_count":10828,"listed_count":1665,"favourites_count":10277,"statuses_count":128001,"created_at":"Sun Mar 02 23:57:10 +0000 2014","utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"pro
# ...

# %% [markdown]
# ## The data that we stored twitter_data.txt is in JSON format

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read the data in into an array that we call tweets.

tweets_data_path = 'twitter_data.txt'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
len(tweets_data)
# Out:
# 248

# %%
# structure the tweets data into a pandas DataFrame to simplify the data manipulation

tweets = pd.DataFrame()

# %%
# add 3 columns to the tweets DataFrame called text, lang, and country. 
# text column contains the tweet,
# lang column contains the language in which the tweet was written, 
# and country the country from which the tweet was sent.

tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)
tweets['lang'] = map(lambda tweet: tweet['lang'], tweets_data)
tweets['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
tweets
# Out:
#                                                   text lang country
# 0    RT @weakroses: 36. ruby\n- hop off max's dick\...   en    None
# 1    Pues ya tengo las 6 medallas de Pokémon Omega ...   es    None
# 2    RT @weakroses: 37. max\n- first of all\n- woul...   en    None
# 3    RT @NolanR: You ladies aren't ready for this p...   en    None
# 4    RT @killthots: y'all really blurred out a snak...   en    None
# 5    RT @vesselatbestt: I would My big toe and my l...   en    None
# 6    RT @briaatortillaa: Did tha snake ask to not b...   en    None
# 7    RT @briaatortillaa: Did tha snake ask to not b...   en    None
# 8    RT @NolanR: You ladies aren't ready for this p...   en    None
# 9    RT @yutakashino: JIT native code generation fo...   ja    None
# 10   New Remote Job: Front End Engineer at DuckDuck...   en    None
# 11   RT @weakroses: 36. ruby\n- hop off max's dick\...   en    None
# 12   Jaa! Lo sabía  Ruby es Caperucita :v\nBuena se...   es    None
# ...

# %%
#The first one describing the Top 5 languages in which the tweets were written

tweets_by_lang = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %% [markdown]
# ## the possible chart show looks like image below
# ![title](https://raw.githubusercontent.com/RubyRuan/ARC6818/master/tweets_top_langs.png)

# %%
tweets_by_country = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')

# %% [markdown]
# ## the possible chart show looks like image below
# ![title](https://raw.githubusercontent.com/RubyRuan/ARC6818/master/tweets_top_countries.png)
