# %% [markdown]
# ## Using Twitter with NLTK

# %% [markdown]
# *First you need to create a __developer account__ with Twitter by signing in to your twitter account on the [twitter apps page](https://apps.twitter.com). Click on __'Create new app'__ and fill in the details. Once your app has been created go to the tab labeled 'Keys and Access Tokens' and copy the following four items: Consumer Key, Consumer Secret, Access Token, Access Token Secret. Then [follow the instructions here](http://www.nltk.org/howto/twitter.html#Storing-your-keys) for storing your keys in a way that's secure and accessible to python. On a Windows system you need to create an environment variable called __TWITTER__ that contains the path to a file called __credentials.txt__ containing your twitter keys and tokens. Once you've done completed these steps you'll be able to use NLTK's Twitter class without specifying this information.*

# %% [markdown]
# *This tutorial uses several modules not included in Anaconda: twython and wordcloud. You can find [instructions for installing twython here](http://www.nltk.org/howto/twitter.html#Install-Twython), and for wordcloud the [installation instructions are here](https://github.com/amueller/word_cloud). The tutorial is based on [this overview of the use of NLTK with Twitter](http://www.nltk.org/howto/twitter.html).*

# %% [markdown]
# *To search or stream from Twitter you first need to import the Twitter module from NLTK*

# %%
from nltk.twitter import Query, Streamer, Twitter, TweetViewer, TweetWriter, credsfromfile

# %% [markdown]
# *__credsfromfile()__ loads the personal tokens and keys using the TWITTER environment variable that you defined above. Once this is defined you can sample the twitter live stream.*

# %%
oauth = credsfromfile()
client = Streamer(**oauth)
client.register(TweetViewer(limit=10))
client.sample()
# Out:
# @arrivayorkshire 09:50 229 from Leeds - arrives 10 mins late, driver then awol for 10 mins, when he eventually sets off he gets lost. #FAIL
# ほんと意味分からん
# RT @kousaki_r: ジャンヌ絵(´ω｀)☆サークル【フレシア】様にて、ＦＧＯジャンヌのプレイマットとスリーブ絵、描かせて頂きました～！■冬コミにて、頒布だそうです。。 https://t.co/rbh4S4pMZm
# RT @Dahyun_today: 161118 뮤직뱅크 in 경주 다현 #트와이스 #TWICE #다현 #dahyun 3 https://t.co/bM7AmtxIPH
# RT @thereaIbanksy: Equality vs. Equity https://t.co/qKb7dRp6T2
# ٢،٣ https://t.co/6ZqgqrAb5B
# Working mood #fashion #madrid #meeting @haydeecallejas @ Elena Benarroch https://t.co/quP2V0shI8
# @sheiskojima
#
# 俺の知ってるラインと違うじゃんもう！
# 【定期】当方、PSYCHO-PASSの狡噛受け(槙狡,佐狡他All OK)推しです。ひっそりと槙狡(非公式自動)botを稼働させてます。キャラ崩壊,狡噛総受け気味など、趣味に走っていますが、興味のある方はツイプロ一読の上、フォロー下さると私が泣いて喜びます。←
# RT @spark57760066: Twitterでは、俺の顔載せるかも……
# てんチャンネルさんのBGMちょっとだけ https://t.co/jTVFei6XW3
# Written 10 Tweets

# %% [markdown]
# *You can also add __keywords__ to filter the results*

# %%
client = Streamer(**oauth)
client.register(TweetViewer(limit=10))
client.filter(track='sad, happy')
# Out:
# @gh0stlyx I'm happy for you
# @NEWEGYPTIANA happy birthday beautiful
# 画像載せてないのに
# 文面だけでこの伸びは自分でも驚き、、
#
# 気持ち伝わったのかな？← https://t.co/kFwY9sytp8
# i hate that feeling when you’re not necessarily sad, but you just feel really empty
# RT @RandeepRinku123: @gurruchoudhary BAHUT KHUBSURAT HAIN ANKHEIN TUMHARI, KIJE INAYAT BANA DIJIYE INKO QISMAT HMARI,HAPPY MAANDAY GCIAN…
# RT @smrookies: HAPPY BIRTHDAY TO #HANSOL ♥️ #SMROOKIES #SR15B #SMROOKIESSHOW https://t.co/yJl9wLyuee
# RT @DamnRealPosts: all i want is a clear mind &amp; happy heart
# @HathwayCreative Had the same problems with them. After reading https://t.co/2EOaMsDLLA now a happy Linux Hosts Ltd customer. Hope it helps!
# Then... Wonder why they can't be happy even being with  billionare my uncle and his wife a million are and they dress work clothes.
# RT @onemorepage: Happy publication day @rowancoleman I've got 5 copies of #TheOtherSister to give away! RT to enter. Full details at…
# Written 10 Tweets

# %% [markdown]
# *You can search the stream of selected twitter __users__*

# %%
client = Query(**oauth)
client.register(TweetViewer(limit=10))
client.user_tweets('GeorgeMonbiot', 10)
# Out:
# This review of our album keeps you guessing until the end about whether it's any good or not: https://t.co/xKPTKj6ua5
# I love the idea of Tony Blair and George Osborne forming a political alliance. Could we find an island for them?
# @rubenbrooke I like that
# @Cupboardy123 not at all. That's exactly the point – there is no choice
# @LaurieCheers I know
# @AnnaGrear @LaurieCheers perhaps not.
# Best so far in my view: the tightrope economy https://t.co/rQc6MinWZd
# @LaurieCheers I like that. The tightrope economy
# @MarktheStars haha!

# %%
client = Query(**oauth)
tweets = client.search_tweets(keywords='nltk', limit=10)
tweet = next(tweets)
from pprint import pprint
pprint(tweet, depth=1)

# %% [markdown]
# *And you can search the Twitter stream for keywords using the __Query class__*

# %%
client = Query(**oauth)
tweets = client.search_tweets(keywords='hillary clinton', limit=10)
tweet = next(tweets)

for tweet in tweets:
    print(tweet['text'])
# Out:
# You’re not just imagining it: the Hillary Clinton vs Donald Trump vote totals do look rigged https://t.co/VZH1AFVYSo
# Bill for First Lady Funny Hillary Clinton Anti-Hillary https://t.co/GDhDBlmutb
# RT @NetworksManager: Say what you want I think deep down Traitor-N-Chief Barack Obama happy Trump won he didn't want that Hillary Rotten Cl…
# RT @LeftSentThis: Obama is doing nothing about #NoDAPL.
# Hillary Clinton said nothing about #NoDAPL.
# Donald Trump is investing in the #NoDA…
# RT @NicholsUprising: Hillary Clinton's popular-vote victory now exceeds that of Presidents:
# Bush/2000
# Carter/1976
# Nixon/1968
# Kennedy/1960
# h…
# RT @NetworksManager: Say what you want I think deep down Traitor-N-Chief Barack Obama happy Trump won he didn't want that Hillary Rotten Cl…
# The public pays heftily for elevating worthless, self- obsessed celebrity arses onto a platform...#kanye #Kardashian https://t.co/7qVaZR74gN
# RT @ZaibatsuNews: Marian Wright Edelman calls Hillary Clinton "The people's president" https://t.co/ZgSuM4khNG #resist #TheResistance https…
# RT @HillaryClinton: Looking forward to honoring some brave young people tonight at @ChildDefender where I started my career. Tune in: https…

# %% [markdown]
# *It's also possible to __extract specific metadata__ from the tweets; a complete reference for the JSON tweet structure is [available here](https://dev.twitter.com/overview/api/tweets). IN the example below we do a search for Hillary Clinton and extract the __location and text__ of each tweet. This information is stored in the list variables __lat__ and __lon__, and the string __myText__.*

# %%
client = Query(**oauth)
tweets = client.search_tweets(keywords='hillary clinton', limit=10000)
tweet = next(tweets)
lat = []
lon = []
myTweets = ""
for tweet in tweets:
    text = tweet['text']
    myTweets += ' ' + text
    coords = tweet["coordinates"]
    if (coords is not None):
        print(coords['coordinates'][0])
        print(coords['coordinates'][1])
        lat.append(coords['coordinates'][0])
        lon.append(coords['coordinates'][1])
# Out:
# 37.9039
# -0.0244
# -118.24533538
# 34.05161048
# -0.19833863
# 51.60664115

# %%
# %matplotlib inline

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %% [markdown]
# *You can produce a map of tweet locations using Basemap or Bokeh*

# %%
fig = plt.figure(figsize=(20, 14))
markersize = 400
markertype = '.'
markercolor = 'red'
markeralpha = 1

m = Basemap(projection='moll',lat_0=lat[0],lon_0=lon[0],resolution='l')
m.drawcoastlines(linewidth=0.25)

# Convert locations to x/y coordinates and plot them as dots.
x, y = m(lat, lon)
m.scatter(x, y, markersize, marker=markertype, color=markercolor, alpha=markeralpha)
plt.show()

# %%
import nltk

def graph(myFile):
  tokens = nltk.tokenize.word_tokenize(myFile)
  fd = nltk.FreqDist(tokens)
  fd.plot(30,cumulative=False)

# %%
graph(myTweets)

# %%
from os import path
from wordcloud import WordCloud, STOPWORDS

# define stopwords: these will be excluded from the wordcloud
stopwords = set(STOPWORDS)
stopwords.add("https")

# Generate a word cloud image
wc = WordCloud(background_color="black", max_words=2000, stopwords=stopwords)
wc.generate(myTweets)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
